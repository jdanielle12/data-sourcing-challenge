# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json
from pandas import json_normalize

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page_num in range(20):
    
    # create query with a page number
    # API results show 10 articles at a time
    query_params = {
    "q": "love",
    "fq": 'section_name:"Movies" AND type_of_material:"Review"',
    "sort": "newest",
    "begin_date": "20130101",
    "end_date": "20230531",
    "fl": "headline,web_url,snippet,source,keywords,pub_date,byline,word_count",
    "api-key": nyt_api_key
}
    query_url = url + "&".join([f"{key}={value}" for key, value in query_params.items()])

    
    # Make a "GET" request and retrieve the JSON
    response = requests.get(query_url)
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        reviews = response.json()

        # loop through the reviews["response"]["docs"] and append each review to the list
        for review in reviews["response"]["docs"]:
            
            reviews_list.append(review)
        
        # Print the page that was just retrieved
        print(f"Checked page {page_num}")

        # Print the page number that had no results then break from the loop
    except:
        print(f"No results found for page {page_num}.")
        break
# Out:
# Checked page 0
# Checked page 1
# Checked page 2
# Checked page 3
# Checked page 4
# Checked page 5
# Checked page 6
# Checked page 7
# Checked page 8
# Checked page 9
# Checked page 10
# Checked page 11
# Checked page 12
# Checked page 13
# Checked page 14
# Checked page 15
# Checked page 16
# Checked page 17
# Checked page 18
# Checked page 19

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(reviews_list[:5], indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/you-hurt-my-feelings-review.html",
#         "snippet": "The director Nicole Holofcener\u2019s characters are known for their brazen honesty. But it\u2019s dishonesty that drives her new film, starring Julia Louis-Dreyfus.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Hurt My Feelings\u2019 Review: She Can\u2019t Handle the Truth",
#             "kicker": "Critic\u2019s Pick",
#             "content_kicker": null,
#             "print_headline": "Welcome to the Little White Lie Club",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Holofcener, Nicole",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Louis-Dreyfus, Julia",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Menzies, Tobias",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Hurt My Feelings (Movie)",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T18:47:33+0000",
#         "byline": {
#             "original": "By Wesley Morris",
#             "person": [
#                 {
#                     "firstname": "Wesley",
#                     "middlename": null,
#                     "lastname": "Morris",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 1039
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/24/movies/little-mermaid-review-halle-bailey.html",
#         "snippet": "Disney\u2019s live-action remake, with Halle Bailey starring as Ariel and a diverse cast, is a dutiful corrective with noble intentions and little fun.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Little Mermaid\u2019 Review: The Renovations Are Only Skin Deep",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Remake Finds Its Feet but Loses Its Bubbles",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Bailey, Halle (2000- )",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Miranda, Lin-Manuel",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Little Mermaid (Movie)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Walt Disney Company",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "McCarthy, Melissa",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Bardem, Javier",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diggs, Daveed",
#                 "rank": 8,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Lum, Nora (Awkwafina)",
#                 "rank": 9,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Marshall, Rob (1960- )",
#                 "rank": 10,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Musker, John",
#                 "rank": 11,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-24T20:34:39+0000",
#         "byline": {
#             "original": "By Wesley Morris",
#             "person": [
#                 {
#                     "firstname": "Wesley",
#                     "middlename": null,
#                     "lastname": "Morris",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 1536
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/18/movies/stay-awake-review.html",
#         "snippet": "This story of a small-town family impacted by addiction succeeds in humanizing its characters but falters when it tries to include a coming-of-age tale.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Stay Awake\u2019 Review: Becoming Their Mother\u2019s Caretakers",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Stay Awake",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Oleff, Wyatt",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Stay Awake (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Sisley, Jamie",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Metz, Chrissy (1980- )",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Argus, Fin",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-18T17:41:48+0000",
#         "byline": {
#             "original": "By Claire Shaffer",
#             "person": [
#                 {
#                     "firstname": "Claire",
#                     "middlename": null,
#                     "lastname": "Shaffer",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 216
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/18/movies/master-gardener-review-paul-schrader.html",
#         "snippet": "The director\u2019s latest movie completes a trilogy about men in search of grace in a brutal world \u2014 usually by way of women, but thankfully they are vivid, too.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Master Gardener\u2019 Review: Paul Schrader\u2019s Solitary Man",
#             "kicker": "Critic\u2019s Pick",
#             "content_kicker": null,
#             "print_headline": "A Man Tends His Garden, With Help",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Edgerton, Joel",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Schrader, Paul",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Swindell, Quintessa",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Weaver, Sigourney",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Master Gardener (Movie)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-18T17:33:25+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 982
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_df = json_normalize(reviews_list)
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/you-...
# 1    https://www.nytimes.com/2023/05/25/movies/the-...
# 2    https://www.nytimes.com/2023/05/24/movies/litt...
# 3    https://www.nytimes.com/2023/05/18/movies/stay...
# 4    https://www.nytimes.com/2023/05/18/movies/mast...
# ..                                                 ...
# 195  https://www.nytimes.com/2023/05/18/movies/the-...
# 196  https://www.nytimes.com/2023/05/16/movies/anna...
# 197  https://www.nytimes.com/2023/05/16/movies/givi...
# 198  https://www.nytimes.com/2023/05/11/movies/the-...
# 199  https://www.nytimes.com/2023/05/11/movies/it-a...
#
#                                                snippet              source  \
# 0    The director Nicole Holofcener’s characters ar...  The New York Times
# 1    A gynecologist and her patient form a horrifyi...  The New York Times
# 2    Disney’s live-action remake, with Halle Bailey...  The New York Times
# 3    This story of a small-town family impacted by ...  The New York Times
# 4    The director’s latest movie completes a trilog...  The New York Times
# ..                                                 ...                 ...
# 195  This lyrical debut feature from Francisca Aleg...  The New York Times
# 196  The tumultuous life and death of the model, ac...  The New York Times
# 197  Steeped in a distinctly American nostalgia, th...  The New York Times
# 198  Eliza Scanlen plays a pious teenager who begin...  The New York Times
# 199  The baseball player, known for his quirky mala...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Documentary Fil...
# 197  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'persons', 'value': 'Berra, Yogi', '...
#
#                      pub_date  word_count  \
# 0    2023-05-25T18:47:33+0000        1039
# 1    2023-05-25T11:00:03+0000         295
# 2    2023-05-24T20:34:39+0000        1536
# 3    2023-05-18T17:41:48+0000         216
# 4    2023-05-18T17:33:25+0000         982
# ..                        ...         ...
# 195  2023-05-18T11:00:03+0000         335
# 196  2023-05-16T16:39:50+0000         321
# 197  2023-05-16T14:46:09+0000         344
# 198  2023-05-11T15:38:38+0000         265
# 199  2023-05-11T11:00:10+0000         519
#
#                                          headline.main headline.kicker  \
# 0    ‘You Hurt My Feelings’ Review: She Can’t Handl...   Critic’s Pick
# 1          ‘The Attachment Diaries’ Review: Love, Sick            None
# 2    ‘The Little Mermaid’ Review: The Renovations A...            None
# 3    ‘Stay Awake’ Review: Becoming Their Mother’s C...            None
# 4    ‘Master Gardener’ Review: Paul Schrader’s Soli...   Critic’s Pick
# ..                                                 ...             ...
# 195  ‘The Cow Who Sang a Song Into the Future’ Revi...   Critic’s Pick
# 196  ‘Anna Nicole Smith: You Don’t Know Me’ Review:...            None
# 197  ‘Giving Birth to a Butterfly’ Review: Melancho...            None
# 198    ‘The Starling Girl’ Review: As the Spirit Moves            None
# 199  ‘It Ain’t Over’ Review: When Yogi Berra Saw a ...   Critic’s Pick
#
#     headline.content_kicker                      headline.print_headline  \
# 0                      None         Welcome to the Little White Lie Club
# 1                      None                       The Attachment Diaries
# 2                      None  Remake Finds Its Feet but Loses Its Bubbles
# 3                      None                                   Stay Awake
# 4                      None            A Man Tends His Garden, With Help
# ..                      ...                                          ...
# 195                    None      The Cow Who Sang A Song Into the Future
# 196                    None        Anna Nicole Smith:  You Don’t Know Me
# 197                    None                  Giving Birth To a Butterfly
# 198                    None                            The Starling Girl
# 199                    None    Accidental Zen Master And Star Ballplayer
#
#     headline.name headline.seo headline.sub         byline.original  \
# 0            None         None         None        By Wesley Morris
# 1            None         None         None  By Jeannette Catsoulis
# 2            None         None         None        By Wesley Morris
# 3            None         None         None       By Claire Shaffer
# 4            None         None         None       By Manohla Dargis
# ..            ...          ...          ...                     ...
# 195          None         None         None           By Brandon Yu
# 196          None         None         None          By Calum Marsh
# 197          None         None         None      By Beatrice Loayza
# 198          None         None         None    By Natalia Winkelman
# 199          None         None         None          By Glenn Kenny
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Wesley', 'middlename': None, '...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Wesley', 'middlename': None, '...                None
# 3    [{'firstname': 'Claire', 'middlename': None, '...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 196  [{'firstname': 'Calum', 'middlename': None, 'l...                None
# 197  [{'firstname': 'Beatrice', 'middlename': None,...                None
# 198  [{'firstname': 'Natalia', 'middlename': None, ...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
# [200 rows x 16 columns]

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
reviews_df["title"] = reviews_df["headline.main"].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/you-...
# 1    https://www.nytimes.com/2023/05/25/movies/the-...
# 2    https://www.nytimes.com/2023/05/24/movies/litt...
# 3    https://www.nytimes.com/2023/05/18/movies/stay...
# 4    https://www.nytimes.com/2023/05/18/movies/mast...
# ..                                                 ...
# 195  https://www.nytimes.com/2023/05/18/movies/the-...
# 196  https://www.nytimes.com/2023/05/16/movies/anna...
# 197  https://www.nytimes.com/2023/05/16/movies/givi...
# 198  https://www.nytimes.com/2023/05/11/movies/the-...
# 199  https://www.nytimes.com/2023/05/11/movies/it-a...
#
#                                                snippet              source  \
# 0    The director Nicole Holofcener’s characters ar...  The New York Times
# 1    A gynecologist and her patient form a horrifyi...  The New York Times
# 2    Disney’s live-action remake, with Halle Bailey...  The New York Times
# 3    This story of a small-town family impacted by ...  The New York Times
# 4    The director’s latest movie completes a trilog...  The New York Times
# ..                                                 ...                 ...
# 195  This lyrical debut feature from Francisca Aleg...  The New York Times
# 196  The tumultuous life and death of the model, ac...  The New York Times
# 197  Steeped in a distinctly American nostalgia, th...  The New York Times
# 198  Eliza Scanlen plays a pious teenager who begin...  The New York Times
# 199  The baseball player, known for his quirky mala...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Documentary Fil...
# 197  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'persons', 'value': 'Berra, Yogi', '...
#
#                      pub_date  word_count  \
# 0    2023-05-25T18:47:33+0000        1039
# 1    2023-05-25T11:00:03+0000         295
# 2    2023-05-24T20:34:39+0000        1536
# 3    2023-05-18T17:41:48+0000         216
# 4    2023-05-18T17:33:25+0000         982
# ..                        ...         ...
# 195  2023-05-18T11:00:03+0000         335
# 196  2023-05-16T16:39:50+0000         321
# 197  2023-05-16T14:46:09+0000         344
# 198  2023-05-11T15:38:38+0000         265
# 199  2023-05-11T11:00:10+0000         519
#
#                                          headline.main headline.kicker  \
# 0    ‘You Hurt My Feelings’ Review: She Can’t Handl...   Critic’s Pick
# 1          ‘The Attachment Diaries’ Review: Love, Sick            None
# 2    ‘The Little Mermaid’ Review: The Renovations A...            None
# 3    ‘Stay Awake’ Review: Becoming Their Mother’s C...            None
# 4    ‘Master Gardener’ Review: Paul Schrader’s Soli...   Critic’s Pick
# ..                                                 ...             ...
# 195  ‘The Cow Who Sang a Song Into the Future’ Revi...   Critic’s Pick
# 196  ‘Anna Nicole Smith: You Don’t Know Me’ Review:...            None
# 197  ‘Giving Birth to a Butterfly’ Review: Melancho...            None
# 198    ‘The Starling Girl’ Review: As the Spirit Moves            None
# 199  ‘It Ain’t Over’ Review: When Yogi Berra Saw a ...   Critic’s Pick
#
#     headline.content_kicker                      headline.print_headline  \
# 0                      None         Welcome to the Little White Lie Club
# 1                      None                       The Attachment Diaries
# 2                      None  Remake Finds Its Feet but Loses Its Bubbles
# 3                      None                                   Stay Awake
# 4                      None            A Man Tends His Garden, With Help
# ..                      ...                                          ...
# 195                    None      The Cow Who Sang A Song Into the Future
# 196                    None        Anna Nicole Smith:  You Don’t Know Me
# 197                    None                  Giving Birth To a Butterfly
# 198                    None                            The Starling Girl
# 199                    None    Accidental Zen Master And Star Ballplayer
#
#     headline.name headline.seo headline.sub         byline.original  \
# 0            None         None         None        By Wesley Morris
# 1            None         None         None  By Jeannette Catsoulis
# 2            None         None         None        By Wesley Morris
# 3            None         None         None       By Claire Shaffer
# 4            None         None         None       By Manohla Dargis
# ..            ...          ...          ...                     ...
# 195          None         None         None           By Brandon Yu
# 196          None         None         None          By Calum Marsh
# 197          None         None         None      By Beatrice Loayza
# 198          None         None         None    By Natalia Winkelman
# 199          None         None         None          By Glenn Kenny
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Wesley', 'middlename': None, '...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Wesley', 'middlename': None, '...                None
# 3    [{'firstname': 'Claire', 'middlename': None, '...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 196  [{'firstname': 'Calum', 'middlename': None, 'l...                None
# 197  [{'firstname': 'Beatrice', 'middlename': None,...                None
# 198  [{'firstname': 'Natalia', 'middlename': None, ...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
#                                        title
# 0                       You Hurt My Feelings
# 1                     The Attachment Diaries
# 2                         The Little Mermaid
# 3                                 Stay Awake
# 4                            Master Gardener
# ..                                       ...
# 195  The Cow Who Sang a Song Into the Future
# 196     Anna Nicole Smith: You Don’t Know Me
# 197              Giving Birth to a Butterfly
# 198                        The Starling Girl
# 199                            It Ain’t Over
#
# [200 rows x 17 columns]

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_df["keywords"] = reviews_df["keywords"].apply(extract_keywords)

print(reviews_df["keywords"])
# Out:
# 0      subject: Movies;persons: Holofcener, Nicole;pe...
# 1      subject: Movies;creative_works: The Attachment...
# 2      subject: Movies;persons: Bailey, Halle (2000- ...
# 3      subject: Movies;persons: Oleff, Wyatt;creative...
# 4      subject: Movies;persons: Edgerton, Joel;person...
#                              ...
# 195    subject: Movies;creative_works: The Cow Who Sa...
# 196    subject: Documentary Films and Programs;subjec...
# 197    subject: Movies;creative_works: Giving Birth t...
# 198    subject: Movies;persons: Scanlen, Eliza;person...
# 199    persons: Berra, Yogi;creative_works: It Ain't ...
# Name: keywords, Length: 200, dtype: object

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles = reviews_df["title"].tolist()
titles
# Out:
# ['You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over',
#  'You Hurt My Feelings',
#  'The Attachment Diaries',
#  'The Little Mermaid',
#  'Stay Awake',
#  'Master Gardener',
#  'The Cow Who Sang a Song Into the Future',
#  'Anna Nicole Smith: You Don’t Know Me',
#  'Giving Birth to a Butterfly',
#  'The Starling Girl',
#  'It Ain’t Over']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1

# Loop through the titles
for title in titles:
    # Check if we need to sleep before making a request
    try:
        request_counter += 1
    # Add 1 to the request counter

    
    # Perform a "GET" request for The Movie Database
        search_url = url + title + tmdb_key_string
        search_response = requests.get(search_url)
        search_results = search_response.json()

        # Get movie id
        if 'results' in search_results and search_results['results']:
            movie_id = search_results['results'][0]['id']

        # Make a request for a the full movie details
            movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}?{tmdb_key_string}"
            movie_response = requests.get(movie_url)
            movie_details = movie_response.json()
        
        # Extract the genre names into a list
        # Extract the spoken_languages' English name into a list
        # Extract the production_countries' name into a list
            genres = [genre['name'] for genre in movie_details['genres']]
            spoken_languages = [lang['english_name'] for lang in movie_details['spoken_languages']]
            production_countries = [country['name'] for country in movie_details['production_countries']]

        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
            movie_dict = {
                'title': movie_details['title'],
                'original_title': movie_details['original_title'],
                'budget': movie_details['budget'],
                'original_language': movie_details['original_language'],
                'homepage': movie_details['homepage'],
                'overview': movie_details['overview'],
                'popularity': movie_details['popularity'],
                'runtime': movie_details['runtime'],
                'revenue': movie_details['revenue'],
                'release_date': movie_details['release_date'],
                'vote_average': movie_details['vote_average'],
                'vote_count': movie_details['vote_count'],
                'genres': genres,
                'spoken_languages': spoken_languages,
                'production_countries': production_countries
            }
        
            tmdb_movies_list.append(movie_dict)
        
        # Print out the title that was found
            print(f"Found movie: {movie_details['title']}")
        
        else:
            print(f"No movie found for title: {title}")
            
            
        if request_counter % 50 == 0:
            print("Sleeping...")
            time.sleep(1)
            
    except Exception as e:
        print(f"Error processing title: {title}, Error: {e}")
# Out:
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Sleeping...
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Sleeping...
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Sleeping...
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Found movie: It Ain’t Over
# Found movie: You Hurt My Feelings
# Found movie: The Attachment Diaries
# Found movie: The Little Mermaid
# Found movie: Stay Awake
# Found movie: Master Gardener
# Found movie: The Cow Who Sang a Song into the Future
# Found movie: Anna Nicole Smith: You Don't Know Me
# Found movie: Giving Birth to a Butterfly
# Found movie: The Starling Girl
# Sleeping...
# Found movie: It Ain’t Over

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(tmdb_movies_list[:5], indent=4))
# Out:
# [
#     {
#         "title": "You Hurt My Feelings",
#         "original_title": "You Hurt My Feelings",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "https://a24films.com/films/you-hurt-my-feelings",
#         "overview": "A novelist's longstanding marriage is suddenly upended when she overhears her husband giving his honest reaction to her latest book.",
#         "popularity": 19.259,
#         "runtime": 93,
#         "revenue": 5000000,
#         "release_date": "2023-05-26",
#         "vote_average": 6.476,
#         "vote_count": 105,
#         "genres": [
#             "Comedy",
#             "Drama",
#             "Romance"
#         ],
#         "spoken_languages": [
#             "English",
#             "Spanish"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "The Attachment Diaries",
#         "original_title": "El apego",
#         "budget": 0,
#         "original_language": "es",
#         "homepage": "",
#         "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#         "popularity": 1.571,
#         "runtime": 102,
#         "revenue": 0,
#         "release_date": "2021-10-07",
#         "vote_average": 3.0,
#         "vote_count": 3,
#         "genres": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "spoken_languages": [
#             "Spanish"
#         ],
#         "production_countries": [
#             "Argentina"
#         ]
#     },
#     {
#         "title": "The Little Mermaid",
#         "original_title": "The Little Mermaid",
#         "budget": 297000000,
#         "original_language": "en",
#         "homepage": "https://movies.disney.com/the-little-mermaid-2023",
#         "overview": "The youngest of King Triton\u2019s daughters, and the most defiant, Ariel longs to find out more about the world beyond the sea, and while visiting the surface, falls for the dashing Prince Eric. With mermaids forbidden to interact with humans, Ariel makes a deal with the evil sea witch, Ursula, which gives her a chance to experience life on land, but ultimately places her life \u2013 and her father\u2019s crown \u2013 in jeopardy.",
#         "popularity": 115.578,
#         "runtime": 135,
#         "revenue": 569600000,
#         "release_date": "2023-05-18",
#         "vote_average": 6.39,
#         "vote_count": 2665,
#         "genres": [
#             "Adventure",
#             "Family",
#             "Fantasy",
#             "Romance"
#         ],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Stay Awake",
#         "original_title": "Stay Awake",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "https://www.stayawakethefilm.com/",
#         "overview": "Set against the backdrop of the prescription drug and opioid crisis in the USA, Jamie Sisley depicts the individual consequences of a societal tragedy, while taking an unflinching yet gentle look at a complicated web of relationships.",
#         "popularity": 10.174,
#         "runtime": 94,
#         "revenue": 0,
#         "release_date": "2023-05-19",
#         "vote_average": 6.0,
#         "vote_count": 2,
#         "genres": [
#             "Drama"
#         ],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Master Gardener",
#         "original_title": "Master Gardener",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "",
#         "overview": "Narvel Roth is a meticulous horticulturist who is devoted to tending the grounds of a beautiful estate and pandering to his employer, the wealthy dowager Mrs. Haverhill. When she demands that he take on her wayward and troubled niece, it unlocks dark secrets from a buried violent past.",
#         "popularity": 25.996,
#         "runtime": 111,
#         "revenue": 563772,
#         "release_date": "2023-05-19",
#         "vote_average": 6.27,
#         "vote_count": 161,
#         "genres": [
#             "Drama",
#             "Romance",
#             "Thriller"
#         ],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "Australia",
#             "United Kingdom",
#             "United States of America"
#         ]
#     }
# ]

# %%
# Convert the results to a DataFrame
tmdb_df = pd.DataFrame(tmdb_movies_list)
tmdb_df
# Out:
#                                        title  \
# 0                       You Hurt My Feelings
# 1                     The Attachment Diaries
# 2                         The Little Mermaid
# 3                                 Stay Awake
# 4                            Master Gardener
# ..                                       ...
# 195  The Cow Who Sang a Song into the Future
# 196     Anna Nicole Smith: You Don't Know Me
# 197              Giving Birth to a Butterfly
# 198                        The Starling Girl
# 199                            It Ain’t Over
#
#                                     original_title     budget  \
# 0                             You Hurt My Feelings          0
# 1                                         El apego          0
# 2                               The Little Mermaid  297000000
# 3                                       Stay Awake          0
# 4                                  Master Gardener          0
# ..                                             ...        ...
# 195  La vaca que canto una cancion sobre el futuro          0
# 196           Anna Nicole Smith: You Don't Know Me          0
# 197                    Giving Birth to a Butterfly          0
# 198                              The Starling Girl          0
# 199                                  It Ain’t Over          0
#
#     original_language                                           homepage  \
# 0                  en    https://a24films.com/films/you-hurt-my-feelings
# 1                  es
# 2                  en  https://movies.disney.com/the-little-mermaid-2023
# 3                  en                  https://www.stayawakethefilm.com/
# 4                  en
# ..                ...                                                ...
# 195                es  https://www.the-match-factory.com/catalogue/fi...
# 196                en             https://www.netflix.com/title/81380540
# 197                en
# 198                en  https://bleeckerstreetmedia.com/the-starling-g...
# 199                en
#
#                                               overview  popularity  runtime  \
# 0    A novelist's longstanding marriage is suddenly...      19.259       93
# 1    Argentina, 1970s. A desperate young woman goes...       1.571      102
# 2    The youngest of King Triton’s daughters, and t...     115.578      135
# 3    Set against the backdrop of the prescription d...      10.174       94
# 4    Narvel Roth is a meticulous horticulturist who...      25.996      111
# ..                                                 ...         ...      ...
# 195  A Chilean family is shaken by the sudden retur...       5.873       99
# 196  From the heights of her modeling fame to her t...       8.020      116
# 197  After having her identity stolen, a woman, and...       7.002       77
# 198  17-year-old Jem Starling struggles with her pl...      50.957      116
# 199  It Ain't Over is the story of the hope of surv...       0.600        0
#
#        revenue release_date  vote_average  vote_count  \
# 0      5000000   2023-05-26         6.476         105
# 1            0   2021-10-07         3.000           3
# 2    569600000   2023-05-18         6.390        2665
# 3            0   2023-05-19         6.000           2
# 4       563772   2023-05-19         6.270         161
# ..         ...          ...           ...         ...
# 195          0   2023-03-24         5.714           7
# 196          0   2023-05-16         6.102          54
# 197          0   2023-05-01         4.000           2
# 198          0   2023-05-12         6.467          30
# 199          0                      0.000           0
#
#                                     genres    spoken_languages  \
# 0                 [Comedy, Drama, Romance]  [English, Spanish]
# 1       [Drama, Mystery, Thriller, Horror]           [Spanish]
# 2    [Adventure, Family, Fantasy, Romance]           [English]
# 3                                  [Drama]           [English]
# 4               [Drama, Romance, Thriller]           [English]
# ..                                     ...                 ...
# 195                                [Drama]           [Spanish]
# 196                          [Documentary]           [English]
# 197               [Drama, Comedy, Mystery]           [English]
# 198                                [Drama]           [English]
# 199                                     []                  []
#
#                                   production_countries
# 0                           [United States of America]
# 1                                          [Argentina]
# 2                           [United States of America]
# 3                           [United States of America]
# 4    [Australia, United Kingdom, United States of A...
# ..                                                 ...
# 195                           [Germany, Chile, France]
# 196                         [United States of America]
# 197                         [United States of America]
# 198         [United Kingdom, United States of America]
# 199                                                 []
#
# [200 rows x 15 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merged_df = pd.merge(reviews_df, tmdb_df, on='title', how='inner')
merged_df
# Out:
#                                                 web_url  \
# 0     https://www.nytimes.com/2023/05/25/movies/you-...
# 1     https://www.nytimes.com/2023/05/25/movies/you-...
# 2     https://www.nytimes.com/2023/05/25/movies/you-...
# 3     https://www.nytimes.com/2023/05/25/movies/you-...
# 4     https://www.nytimes.com/2023/05/25/movies/you-...
# ...                                                 ...
# 3195  https://www.nytimes.com/2023/05/11/movies/it-a...
# 3196  https://www.nytimes.com/2023/05/11/movies/it-a...
# 3197  https://www.nytimes.com/2023/05/11/movies/it-a...
# 3198  https://www.nytimes.com/2023/05/11/movies/it-a...
# 3199  https://www.nytimes.com/2023/05/11/movies/it-a...
#
#                                                 snippet              source  \
# 0     The director Nicole Holofcener’s characters ar...  The New York Times
# 1     The director Nicole Holofcener’s characters ar...  The New York Times
# 2     The director Nicole Holofcener’s characters ar...  The New York Times
# 3     The director Nicole Holofcener’s characters ar...  The New York Times
# 4     The director Nicole Holofcener’s characters ar...  The New York Times
# ...                                                 ...                 ...
# 3195  The baseball player, known for his quirky mala...  The New York Times
# 3196  The baseball player, known for his quirky mala...  The New York Times
# 3197  The baseball player, known for his quirky mala...  The New York Times
# 3198  The baseball player, known for his quirky mala...  The New York Times
# 3199  The baseball player, known for his quirky mala...  The New York Times
#
#                                                keywords  \
# 0     subject: Movies;persons: Holofcener, Nicole;pe...
# 1     subject: Movies;persons: Holofcener, Nicole;pe...
# 2     subject: Movies;persons: Holofcener, Nicole;pe...
# 3     subject: Movies;persons: Holofcener, Nicole;pe...
# 4     subject: Movies;persons: Holofcener, Nicole;pe...
# ...                                                 ...
# 3195  persons: Berra, Yogi;creative_works: It Ain't ...
# 3196  persons: Berra, Yogi;creative_works: It Ain't ...
# 3197  persons: Berra, Yogi;creative_works: It Ain't ...
# 3198  persons: Berra, Yogi;creative_works: It Ain't ...
# 3199  persons: Berra, Yogi;creative_works: It Ain't ...
#
#                       pub_date  word_count  \
# 0     2023-05-25T18:47:33+0000        1039
# 1     2023-05-25T18:47:33+0000        1039
# 2     2023-05-25T18:47:33+0000        1039
# 3     2023-05-25T18:47:33+0000        1039
# 4     2023-05-25T18:47:33+0000        1039
# ...                        ...         ...
# 3195  2023-05-11T11:00:10+0000         519
# 3196  2023-05-11T11:00:10+0000         519
# 3197  2023-05-11T11:00:10+0000         519
# 3198  2023-05-11T11:00:10+0000         519
# 3199  2023-05-11T11:00:10+0000         519
#
#                                           headline.main headline.kicker  \
# 0     ‘You Hurt My Feelings’ Review: She Can’t Handl...   Critic’s Pick
# 1     ‘You Hurt My Feelings’ Review: She Can’t Handl...   Critic’s Pick
# 2     ‘You Hurt My Feelings’ Review: She Can’t Handl...   Critic’s Pick
# 3     ‘You Hurt My Feelings’ Review: She Can’t Handl...   Critic’s Pick
# 4     ‘You Hurt My Feelings’ Review: She Can’t Handl...   Critic’s Pick
# ...                                                 ...             ...
# 3195  ‘It Ain’t Over’ Review: When Yogi Berra Saw a ...   Critic’s Pick
# 3196  ‘It Ain’t Over’ Review: When Yogi Berra Saw a ...   Critic’s Pick
# 3197  ‘It Ain’t Over’ Review: When Yogi Berra Saw a ...   Critic’s Pick
# 3198  ‘It Ain’t Over’ Review: When Yogi Berra Saw a ...   Critic’s Pick
# 3199  ‘It Ain’t Over’ Review: When Yogi Berra Saw a ...   Critic’s Pick
#
#      headline.content_kicker                    headline.print_headline  ...  \
# 0                       None       Welcome to the Little White Lie Club  ...
# 1                       None       Welcome to the Little White Lie Club  ...
# 2                       None       Welcome to the Little White Lie Club  ...
# 3                       None       Welcome to the Little White Lie Club  ...
# 4                       None       Welcome to the Little White Lie Club  ...
# ...                      ...                                        ...  ...
# 3195                    None  Accidental Zen Master And Star Ballplayer  ...
# 3196                    None  Accidental Zen Master And Star Ballplayer  ...
# 3197                    None  Accidental Zen Master And Star Ballplayer  ...
# 3198                    None  Accidental Zen Master And Star Ballplayer  ...
# 3199                    None  Accidental Zen Master And Star Ballplayer  ...
#
#                                                overview popularity runtime  \
# 0     A novelist's longstanding marriage is suddenly...     19.259      93
# 1     A novelist's longstanding marriage is suddenly...     19.259      93
# 2     A novelist's longstanding marriage is suddenly...     19.259      93
# 3     A novelist's longstanding marriage is suddenly...     19.259      93
# 4     A novelist's longstanding marriage is suddenly...     19.259      93
# ...                                                 ...        ...     ...
# 3195  It Ain't Over is the story of the hope of surv...      0.600       0
# 3196  It Ain't Over is the story of the hope of surv...      0.600       0
# 3197  It Ain't Over is the story of the hope of surv...      0.600       0
# 3198  It Ain't Over is the story of the hope of surv...      0.600       0
# 3199  It Ain't Over is the story of the hope of surv...      0.600       0
#
#       revenue release_date vote_average vote_count                    genres  \
# 0     5000000   2023-05-26        6.476        105  [Comedy, Drama, Romance]
# 1     5000000   2023-05-26        6.476        105  [Comedy, Drama, Romance]
# 2     5000000   2023-05-26        6.476        105  [Comedy, Drama, Romance]
# 3     5000000   2023-05-26        6.476        105  [Comedy, Drama, Romance]
# 4     5000000   2023-05-26        6.476        105  [Comedy, Drama, Romance]
# ...       ...          ...          ...        ...                       ...
# 3195        0                     0.000          0                        []
# 3196        0                     0.000          0                        []
# 3197        0                     0.000          0                        []
# 3198        0                     0.000          0                        []
# 3199        0                     0.000          0                        []
#
#         spoken_languages        production_countries
# 0     [English, Spanish]  [United States of America]
# 1     [English, Spanish]  [United States of America]
# 2     [English, Spanish]  [United States of America]
# 3     [English, Spanish]  [United States of America]
# 4     [English, Spanish]  [United States of America]
# ...                  ...                         ...
# 3195                  []                          []
# 3196                  []                          []
# 3197                  []                          []
# 3198                  []                          []
# 3199                  []                          []
#
# [3200 rows x 31 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ['genres', 'spoken_languages', 'production_countries']

# Create a list of characters to remove
characters_to_remove = ["[", "]", "'"]

# Loop through the list of columns to fix
for column in columns_to_fix:
    # Convert the column to type 'str'
    merged_df[column] = merged_df[column].astype(str)

    # Loop through characters to remove
    for char in characters_to_remove:
        merged_df[column] = merged_df[column].str.replace(char, '')

# Display the fixed DataFrame
merged_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/you-...
# 1  https://www.nytimes.com/2023/05/25/movies/you-...
# 2  https://www.nytimes.com/2023/05/25/movies/you-...
# 3  https://www.nytimes.com/2023/05/25/movies/you-...
# 4  https://www.nytimes.com/2023/05/25/movies/you-...
#
#                                              snippet              source  \
# 0  The director Nicole Holofcener’s characters ar...  The New York Times
# 1  The director Nicole Holofcener’s characters ar...  The New York Times
# 2  The director Nicole Holofcener’s characters ar...  The New York Times
# 3  The director Nicole Holofcener’s characters ar...  The New York Times
# 4  The director Nicole Holofcener’s characters ar...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;persons: Holofcener, Nicole;pe...
# 1  subject: Movies;persons: Holofcener, Nicole;pe...
# 2  subject: Movies;persons: Holofcener, Nicole;pe...
# 3  subject: Movies;persons: Holofcener, Nicole;pe...
# 4  subject: Movies;persons: Holofcener, Nicole;pe...
#
#                    pub_date  word_count  \
# 0  2023-05-25T18:47:33+0000        1039
# 1  2023-05-25T18:47:33+0000        1039
# 2  2023-05-25T18:47:33+0000        1039
# 3  2023-05-25T18:47:33+0000        1039
# 4  2023-05-25T18:47:33+0000        1039
#
#                                        headline.main headline.kicker  \
# 0  ‘You Hurt My Feelings’ Review: She Can’t Handl...   Critic’s Pick
# 1  ‘You Hurt My Feelings’ Review: She Can’t Handl...   Critic’s Pick
# 2  ‘You Hurt My Feelings’ Review: She Can’t Handl...   Critic’s Pick
# 3  ‘You Hurt My Feelings’ Review: She Can’t Handl...   Critic’s Pick
# 4  ‘You Hurt My Feelings’ Review: She Can’t Handl...   Critic’s Pick
#
#   headline.content_kicker               headline.print_headline  ...  \
# 0                    None  Welcome to the Little White Lie Club  ...
# 1                    None  Welcome to the Little White Lie Club  ...
# 2                    None  Welcome to the Little White Lie Club  ...
# 3                    None  Welcome to the Little White Lie Club  ...
# 4                    None  Welcome to the Little White Lie Club  ...
#
#                                             overview popularity runtime  \
# 0  A novelist's longstanding marriage is suddenly...     19.259      93
# 1  A novelist's longstanding marriage is suddenly...     19.259      93
# 2  A novelist's longstanding marriage is suddenly...     19.259      93
# 3  A novelist's longstanding marriage is suddenly...     19.259      93
# 4  A novelist's longstanding marriage is suddenly...     19.259      93
#
#    revenue release_date vote_average vote_count                  genres  \
# 0  5000000   2023-05-26        6.476        105  Comedy, Drama, Romance
# 1  5000000   2023-05-26        6.476        105  Comedy, Drama, Romance
# 2  5000000   2023-05-26        6.476        105  Comedy, Drama, Romance
# 3  5000000   2023-05-26        6.476        105  Comedy, Drama, Romance
# 4  5000000   2023-05-26        6.476        105  Comedy, Drama, Romance
#
#    spoken_languages      production_countries
# 0  English, Spanish  United States of America
# 1  English, Spanish  United States of America
# 2  English, Spanish  United States of America
# 3  English, Spanish  United States of America
# 4  English, Spanish  United States of America
#
# [5 rows x 31 columns]

# %%
# Drop "byline.person" column

# %%
# Delete duplicate rows and reset index
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#                               genre language spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror       es          Spanish
# 1                    Drama, Romance       en  French, English
# 2            Romance, Drama, Comedy       en          English
# 3                       Documentary       en
# 4                             Drama       en          English
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# 4  https://www.focusfeatures.com/a-thousand-and-one/
#
#                                             overview  popularity  runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...       0.708      102
# 1  When Jaime, a gay teenager, is sent to live in...      12.027       96
# 2  Emma and Jesse are living the perfect life tog...      28.872      100
# 3  May Pang lovingly recounts her life in rock & ...       2.368       97
# 4  Struggling but unapologetically living on her ...      11.704      116
#
#    ...  word_count                                      headline.main  \
# 0  ...         295        ‘The Attachment Diaries’ Review: Love, Sick
# 1  ...         294  ‘You Can Live Forever’ Review: Do You Love Me ...
# 2  ...         320     ‘One True Loves’ Review: A Romance Lost at Sea
# 3  ...         327  ‘The Lost Weekend: A Love Story’ Review: When ...
# 4  ...         971  ‘A Thousand and One’ Review: A New York Love S...
#
#    headline.kicker  headline.content_kicker  \
# 0             None                     None
# 1             None                     None
# 2             None                     None
# 3             None                     None
# 4    Critic’s Pick                     None
#
#                    headline.print_headline headline.name headline.seo  \
# 0                   The Attachment Diaries          None         None
# 1                     You Can Live Forever          None         None
# 2                           One True Loves          None         None
# 3          The Lost Weekend:  A Love Story          None         None
# 4  An Unbending Will Meets a Shifting City          None         None
#
#   headline.sub           byline.original byline.organization
# 0         None    By Jeannette Catsoulis                None
# 1         None  By Elisabeth Vincentelli                None
# 2         None             By Brandon Yu                None
# 3         None            By Glenn Kenny                None
# 4         None         By Manohla Dargis                None
#
# [5 rows x 30 columns]

# %%
# Export data to CSV without the index
